# %%
# Library Import(numpy and matplotlib)
import matplotlib.pyplot as plot
import pandas as pd

# Make a data definition
_data = {'Linear Regression': [0.81,0.92,0.68,0.84],
        'Logistic Regression': [0.91,0.97,0.81,0.87],
          'Decision Tree': [0.92,0.92,0.78,0.81],
 'SVM': [0.98,1,0.89,0.89],
  'Random Forest': [0.97,0.95,0.84,0.87],
   'XGBoost Classifier': [1,1,0.90,0.94]
         }


_df = pd.DataFrame(_data,columns=['Linear Regression','Logistic Regression','Decision Tree','SVM','Random Forest','XGBoost Classifier'], index = ['Dataset1', 'Dataset2', 'Dataset3','Dataset3 with PCA'])

# Multiple bar chart
_df.plot.barh()
#margin
##plt.subplots_adjust(bottom= 0.2, top = 0.98)
plot.tight_layout()
# Display the plot
#plot.show()

# %%
_df.plot(kind="barh",figsize=(18, 12))
plot.show()
